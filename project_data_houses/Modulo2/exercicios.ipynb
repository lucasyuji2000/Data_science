# %%
import pandas as pd

# %%
# Lendo os dados
df = pd.read_csv(r'C:\Users\lucas\Estudos\_CDS\repos\python_zero_ds\data\kc_house_data.csv')
df.shape
# Out:
# (21613, 21)

# %%
# Limpando os dados duplicados
df.drop_duplicates('id', inplace=True)
df.shape
# Out:
# (21436, 21)

# %% [markdown]
# ## 1. Crie uma coluna chamada 'house_age'
#     - Se a data da coluna 'date' for maior ou igual que 2014-01-01 : 'new_house'
#     - Se a data da coluna 'date' for menor que 2014-01-01 : 'old_house'

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above              float64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %%
df['house_age'] = df['date'].apply(lambda x: 'new_house' if x >= pd.to_datetime('2014-01-01') else 'old_house')
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ## 2. Crie uma coluna chamada 'dormitory_type'
#     - Se o valor da coluna 'bedrooms' for == 1 : 'studio'
#     - Se o valor da coluna 'bedrooms' for == 2 : 'apartment'
#     - Se o valor da coluna 'bedrooms' for > 2 : 'house'

# %%
# Verificando se nao existem valores negativos ou 0
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
df['dormitory_type'] = df['bedrooms'].apply(lambda x: 'studio' if x == 1 else 
                                                      'apartment' if x == 2 else 
                                                      'house' if x > 2 else 'NA') # por ter valores = 0
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df[df['dormitory_type'] == 'NA']
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 875    6306400140 2014-06-12  1095000.0         0       0.00         3064
# 3119   3918400017 2015-02-05   380000.0         0       0.00         1470
# 3467   1453602309 2014-08-05   288000.0         0       1.50         1430
# 4868   6896300380 2014-10-02   228000.0         0       1.00          390
# 6994   2954400190 2014-06-24  1295650.0         0       0.00         4810
# 8477   2569500210 2014-11-17   339950.0         0       2.50         2290
# 8484   2310060040 2014-09-25   240000.0         0       2.50         1810
# 9773   3374500520 2015-04-29   355000.0         0       0.00         2460
# 9854   7849202190 2014-12-23   235000.0         0       0.00         1470
# 12653  7849202299 2015-02-18   320000.0         0       2.50         1490
# 14423  9543000205 2015-04-13   139950.0         0       0.00          844
# 18379  1222029077 2014-10-29   265000.0         0       0.75          384
# ...

# %% [markdown]
# ## 3. Crie uma coluna chamada 'condition_type'
#     - Se o valor da coluna 'condition' for <= 2 : 'bad'
#     - Se o valor da coluna 'condition' for == [3,4] : 'regular'
#     - Se o valor da coluna 'condition' for == 5 : 'good'

# %%
df['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %%
df['condition_type'] = df['condition'].apply(lambda x: 'bad' if x <= 2 else
                                                       'regular' if x == 3 or x == 4 else 'good' )
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  house_age  dormitory_type  \
# ...

# %% [markdown]
# ## 4. Modifique o type da coluna 'condition' para string(object)

# %%
df['condition'].dtypes
# Out:
# dtype('int64')

# %%
df['condition'] = df['condition'].astype(object) # poderia ser usado str tbb

# %%
df['condition'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## 5. Delete as colunas 'sqft_living15' e 'sqft_lot15'

# %%
df.drop(columns = ['sqft_living15', 'sqft_lot15'], inplace=True)
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ... sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...     1180.0              0
# 1      7242     2.0           0     0  ...     2170.0            400
# 2     10000     1.0           0     0  ...      770.0              0
# 3      5000     1.0           0     0  ...     1050.0            910
# 4      8080     1.0           0     0  ...     1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  house_age  \
# 0      1955             0    98178  47.5112 -122.257  new_house
# ...

# %% [markdown]
# ## 6. Modifique o type da coluna 'yr_built' para date

# %%
df['yr_built'] = pd.to_datetime(df['yr_built'], format='%Y')
df['yr_built'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## 7. Modifique o type da coluna 'yr_renovated' para date

# %%
df['yr_renovated'].unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944], dtype=int64)

# %%
df['yr_renovated'] = df['yr_renovated'].apply(lambda x: pd.to_datetime('1899', format='%Y') if x == 0 else pd.to_datetime(x, format='%Y'))

# %%
df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ... sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ## 8.Qual a data mais antiga de construção de um imovel?

# %%
df['yr_built'].min()
# Out:
# Timestamp('1900-01-01 00:00:00')

# %% [markdown]
# ## 9.Qual a data mais antiga de renovação de um imóvel?

# %%
df[df['yr_renovated'] != pd.to_datetime('1899-01-01')]['yr_renovated'].min()
# Out:
# Timestamp('1934-01-01 00:00:00')

# %% [markdown]
# ## 10. Quantos imoveis tem 2 andares?

# %%
df[df['floors'] == 2].shape
# Out:
# (8209, 22)

# %% [markdown]
# ## 11. Quantos imoveis estao com a condicao igual a regular?

# %%
df[df['condition_type'] == 'regular']['id'].size
# Out:
# 19556

# %% [markdown]
# ## 12. Quantos imoveis estao com a condicao igual a 'bad' e possuem vista para agua?

# %%
df[(df['condition_type'] == 'bad') & (df['waterfront'] == 1)]['id'].size
# Out:
# 2

# %% [markdown]
# ## 13.Quantos imoveis estao com condicao igual a 'good' e sao 'new_house'?

# %%
# Outro jeito de fzr (igual a de cima)
df.query("condition_type == 'good' and house_age == 'new_house'")['id'].size
# Out:
# 1687

# %% [markdown]
# ## 14. Qual o valor do imovel mais caro do tipo 'studio'?

# %%
df[df['dormitory_type'] == 'studio']['price'].max()
# Out:
# 1247000.0

# %%
# Outro metodo
df.loc[df['dormitory_type'] == 'studio', 'price'].max()
# Out:
# 1247000.0

# %% [markdown]
# ## 15. Quantos imoveis do tipo 'apartment' foram reformados em 2015?

# %%
df[(df['dormitory_type'] == 'apartment') & (df['yr_renovated'] == pd.to_datetime('2015-01-01'))].shape[0]
# Out:
# 0

# %% [markdown]
# ## 16. Qual o maior numero de quartos que um imovel do tipo 'house' possui?

# %%
df[df['dormitory_type'] == 'house']['bedrooms'].max()
# Out:
# 33

# %% [markdown]
# ## 17. Quantos imoveis 'new_house' foram reformados em 2014?

# %%
df[(df['house_age'] == 'new_house') & (df['yr_renovated'] == pd.to_datetime('2014-01-01'))].shape[0]
# Out:
# 91

# %% [markdown]
# ## 18. Selecione as colunas: 'id', 'date', 'price', 'floors', 'zipcode' pelo metodo:
#     - Direto pelo nome das colunas
#     - Pelos indices
#     - Pelos indices das linhas e nome das colunas
#     - Pelos indices Booleanos

# %%
# 1.
df[['id', 'date', 'price', 'floors', 'zipcode']]
# Out:
#                id       date     price  floors  zipcode
# 0      7129300520 2014-10-13  221900.0     1.0    98178
# 1      6414100192 2014-12-09  538000.0     2.0    98125
# 2      5631500400 2015-02-25  180000.0     1.0    98028
# 3      2487200875 2014-12-09  604000.0     1.0    98136
# 4      1954400510 2015-02-18  510000.0     1.0    98074
# ...           ...        ...       ...     ...      ...
# 21608   263000018 2014-05-21  360000.0     3.0    98103
# 21609  6600060120 2015-02-23  400000.0     2.0    98146
# 21610  1523300141 2014-06-23  402101.0     2.0    98144
# 21611   291310100 2015-01-16  400000.0     2.0    98027
# 21612  1523300157 2014-10-15  325000.0     2.0    98144
#
# [21436 rows x 5 columns]

# %%
# 2.
df.iloc[:, [0, 1, 2, 7, 16]]
# Out:
#                id       date     price  floors  zipcode
# 0      7129300520 2014-10-13  221900.0     1.0    98178
# 1      6414100192 2014-12-09  538000.0     2.0    98125
# 2      5631500400 2015-02-25  180000.0     1.0    98028
# 3      2487200875 2014-12-09  604000.0     1.0    98136
# 4      1954400510 2015-02-18  510000.0     1.0    98074
# ...           ...        ...       ...     ...      ...
# 21608   263000018 2014-05-21  360000.0     3.0    98103
# 21609  6600060120 2015-02-23  400000.0     2.0    98146
# 21610  1523300141 2014-06-23  402101.0     2.0    98144
# 21611   291310100 2015-01-16  400000.0     2.0    98027
# 21612  1523300157 2014-10-15  325000.0     2.0    98144
#
# [21436 rows x 5 columns]

# %%
# 3.
df.loc[:, ['id', 'date', 'price', 'floors', 'zipcode']]
# Out:
#                id       date     price  floors  zipcode
# 0      7129300520 2014-10-13  221900.0     1.0    98178
# 1      6414100192 2014-12-09  538000.0     2.0    98125
# 2      5631500400 2015-02-25  180000.0     1.0    98028
# 3      2487200875 2014-12-09  604000.0     1.0    98136
# 4      1954400510 2015-02-18  510000.0     1.0    98074
# ...           ...        ...       ...     ...      ...
# 21608   263000018 2014-05-21  360000.0     3.0    98103
# 21609  6600060120 2015-02-23  400000.0     2.0    98146
# 21610  1523300141 2014-06-23  402101.0     2.0    98144
# 21611   291310100 2015-01-16  400000.0     2.0    98027
# 21612  1523300157 2014-10-15  325000.0     2.0    98144
#
# [21436 rows x 5 columns]

# %%
# 4.
#df.loc[:, [True, False...]]

# %% [markdown]
# ## 19. Salve um arquivo CSV com somente as colunas do item 10 ao 17

# %%
df.iloc[:, 10:18].to_csv(r'C:\Users\lucas\Estudos\_CDS\repos\python_zero_ds\data\ex19.csv', index=False)

# %% [markdown]
# ## 20. Modifique a cor dos pontos no mapa de 'pink' para 'verde escuro'
